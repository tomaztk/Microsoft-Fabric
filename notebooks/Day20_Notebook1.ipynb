# %%
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np
# Out:
# StatementMeta(, e8db53e8-eae0-4a69-aa0b-21f9feed2152, 4, Finished, Available)

# %%
def interactive_plot(amplitude, frequency):
    x = np.linspace(0, 2 * np.pi, 1000)
    y = amplitude * np.sin(frequency * x)
    plt.figure(figsize=(8, 4))
    plt.plot(x, y)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Interactive Sine Wave')
    plt.grid(True)
    plt.show()
# Out:
# StatementMeta(, e8db53e8-eae0-4a69-aa0b-21f9feed2152, 5, Finished, Available)

# %%
interact(interactive_plot, amplitude=(1, 5, 0.1), frequency=(1, 10, 0.1))

# %%
# Store data
data = 'Some random results from the test'
# %store data
# Out:
# StatementMeta(, 981dbc44-f83a-4fee-a8b1-0fb78a9c3a8c, 3, Finished, Available)
# Stored 'data' (str)

# %%
# %store
# Out:
# StatementMeta(, 981dbc44-f83a-4fee-a8b1-0fb78a9c3a8c, 4, Finished, Available)
# Stored variables and their in-db values:
# data             -> 'Some random results from the test'
